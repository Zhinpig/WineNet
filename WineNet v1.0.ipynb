# %%
from fastai.vision.all import *
from fastai.vision.widgets import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-d2d29be66561> in <module>()
# ----> 1 from fastai.vision.all import *
#       2 from fastai.vision.widgets import *
#
# ModuleNotFoundError: No module named 'fastai.vision.all'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# # **WineNet v1.0**
# Instructions
#
# Upload an image with the 'Upload' button.
# Classify image with the 'Classify' button.
# Repeat until fully satisfied.

# %%
path = Path()
learn_inf = load_learner(path/'WinNet_export.pkl', cpu=True)
btn_upload = widgets.FileUpload()
out_pl = widgets.Output()
lbl_pred = widgets.Label()
btn_run = widgets.Button(description='Classify')

# %%
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    # Re-label predictions
    if pred == 'red wine':
      pred = 'Red Wine'
    if pred == 'white wine':
      pred = 'White Wine'
    
    confidence_level = round((float(probs[pred_idx]) * 100), 2) # Set probability figure to value out of 100
    lbl_pred.value = f'Prediction: {pred}; Confidence level: {confidence_level}%'
    btn_upload.value.clear()
    btn_upload._counter = 0

btn_run.on_click(on_click_classify)

# %%
VBox([widgets.Label('Upload your tank image!'), 
      btn_upload, btn_run, out_pl, lbl_pred])

# %% [markdown]
# # **WineNet - The Superior Wine Identification Algorithm**
# **Find out what you're drinking with WineNet!**
#
# When you've had a few too many drinks and your vision is swimming, accidentally mixing up your red wine with your white wine is the last thing you need. That's where WineNet comes in - it's guaranteed to distinguish between red wine and white wine at a glance. Just upload to a picture of the wine in question, and WineNet will do the rest!
#
# Picture the scene - **your colleagues have pressured you to drink a few too many glasses at work drinks**, and the world is starting to blur. Out of the blue, someone asks, "Hi! Could you pass me the red wine?" We all know that it's at moments like these that a product like WineNet could save a great deal of social pain. Now with WineNet, all it takes is a surreptious photo upload for you to be certain that you've picked up the correct wine.
#
# Note: Novelty AI Inc. cannot guarantee that WineNet will always correctly classify red wine and white wine.
